# %%
import pymongo
from pymongo import MongoClient, UpdateOne
import pprint
from IPython.display import clear_output
import certifi

ca = certifi.where()

client = MongoClient("mongodb+srv://analytics:analytics-password@mflix.zt8qs.mongodb.net/mflix?retryWrites=true&w=majority", tlsCAFile=ca)

filter = {
    'languages': "English"
}

projection = {
    'title': 1,
    'languages': 1
}

clear_output()
pprint.pprint(list(client.mflix.movies_scratch.find(filter, projection)))
# Out:
# [{'_id': ObjectId('61e618c4f599bd3513db4655'),
#   'languages': ['English'],
#   'title': 'Panorama of Esplanade by Night'},
#  {'_id': ObjectId('61e618c4f599bd3513db4656'),
#   'languages': ['English'],
#   'title': 'Jack and the Beanstalk'},
#  {'_id': ObjectId('61e618c4f599bd3513db4659'),
#   'languages': ['English'],
#   'title': 'Life of an American Fireman'},
#  {'_id': ObjectId('61e618c4f599bd3513db465a'),
#   'languages': ['English'],
#   'title': 'The Great Train Robbery'},
#  {'_id': ObjectId('61e618c4f599bd3513db4661'),
#   'languages': ['English'],
#   'title': 'The Land Beyond the Sunset'},
#  {'_id': ObjectId('61e618c4f599bd3513db4664'),
#   'languages': ['English'],
#   'title': "The '?' Motorist"},
#  {'_id': ObjectId('61e618c4f599bd3513db4665'),
#   'languages': ['English'],
#   'title': 'Dream of a Rarebit Fiend'},
#  {'_id': ObjectId('61e618c4f599bd3513db466b'),
#   'languages': ['English'],
#   'title': 'The Country Doctor'},
#  {'_id': ObjectId('61e618c4f599bd3513db466c'),
#   'languages': ['English'],
#   'title': 'The Lonely Villa'},
#  {'_id': ObjectId('61e618c4f599bd3513db466d'),
#   'languages': ['English'],
#   'title': 'A Corner in Wheat'},
#  {'_id': ObjectId('61e618c4f599bd3513db466e'),
#   'languages': ['English'],
#   'title': 'The Sealed Room'},
#  {'_id': ObjectId('61e618c4f599bd3513db466f'),
#   'languages': ['English'],
#   'title': 'Those Awful Hats'},
#  {'_id': ObjectId('61e618c4f599bd3513db4671'),
#   'languages': ['English'],
#   'title': 'Frankenstein'},
#  {'_id': ObjectId('61e618c4f599bd3513db4672'),
#   'languages': ['English'],
#   'title': 'In the Border States'},
#  {'_id': ObjectId('61e618c4f599bd3513db4673'),
#   'languages': ['English'],
#   'title': 'The Unchanging Sea'},
#  {'_id': ObjectId('61e618c4f599bd3513db4674'),
#   'languages': ['English'],
#   'title': 'The Wonderful Wizard of Oz'},
#  {'_id': ObjectId('61e618c4f599bd3513db4675'),
#   'languages': ['English'],
#   'title': 'Her Crowning Glory'},
#  {'_id': ObjectId('61e618c4f599bd3513db4677'),
#   'languages': ['English'],
#   'title': 'The Lonedale Operator'},
#  {'_id': ObjectId('61e618c4f599bd3513db4678'),
#   'languages': ['English'],
#   'title': 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His '
#            'Moving Comics'},
#  {'_id': ObjectId('61e618c4f599bd3513db4679'),
#   'languages': ['English'],
#   'title': "The Miser's Heart"},
#  {'_id': ObjectId('61e618c4f599bd3513db467a'),
#   'languages': ['English'],
#   'title': 'Cleopatra'},
#  {'_id': ObjectId('61e618c4f599bd3513db467b'),
#   'languages': ['English'],
#   'title': 'A Beast at Bay'},
#  {'_id': ObjectId('61e618c4f599bd3513db467d'),
#   'languages': ['English'],
#   'title': "The Burglar's Dilemma"},
#  {'_id': ObjectId('61e618c4f599bd3513db467f'),
#   'languages': ['English'],
#   'title': 'The Mender of Nets'},
#  {'_id': ObjectId('61e618c4f599bd3513db4680'),
#   'languages': ['English'],
#   'title': 'The New York Hat'},
#  {'_id': ObjectId('61e618c4f599bd3513db4681'),
#   'languages': ['English'],
#   'title': 'The Musketeers of Pig Alley'},
#  {'_id': ObjectId('61e618c4f599bd3513db4682'),
#   'languages': ['English'],
#   'title': 'The Painted Lady'},
#  {'_id': ObjectId('61e618c4f599bd3513db4683'),
#   'languages': ['English'],
#   'title': 'The Life and Death of King Richard III'},
#  {'_id': ObjectId('61e618c4f599bd3513db4685'),
#   'languages': ['English'],
#   'title': "Death's Marathon"},
#  {'_id': ObjectId('61e618c4f599bd3513db4687'),
#   'languages': ['English'],
#   'title': 'The House of Darkness'},
#  {'_id': ObjectId('61e618c4f599bd3513db4689'),
#   'languages': ['English'],
#   'title': 'The Inside of the White Slave Traffic'},
#  {'_id': ObjectId('61e618c4f599bd3513db468c'),
#   'languages': ['German', 'English'],
#   'title': 'The Student of Prague'},
#  {'_id': ObjectId('61e618c4f599bd3513db468d'),
#   'languages': ['English'],
#   'title': 'Traffic in Souls'},
#  {'_id': ObjectId('61e618c4f599bd3513db468f'),
#   'languages': ['English'],
#   'title': "The Avenging Conscience: or 'Thou Shalt Not Kill'"},
#  {'_id': ObjectId('61e618c4f599bd3513db4691'),
#   'languages': ['English'],
#   'title': 'The Battle at Elderbush Gulch'},
#  {'_id': ObjectId('61e618c4f599bd3513db4692'),
#   'languages': ['English'],
#   'title': 'Cinderella'},
#  {'_id': ObjectId('61e618c4f599bd3513db4695'),
#   'languages': ['English'],
#   'title': 'Gertie the Dinosaur'},
#  {'_id': ObjectId('61e618c4f599bd3513db4697'),
#   'languages': ['English'],
#   'title': 'His Musical Career'},
#  {'_id': ObjectId('61e618c4f599bd3513db4698'),
#   'languages': ['English'],
#   'title': 'His New Profession'},
#  {'_id': ObjectId('61e618c4f599bd3513db4699'),
#   'languages': ['English'],
#   'title': 'Hypocrites'},
#  {'_id': ObjectId('61e618c4f599bd3513db469a'),
#   'languages': ['English'],
#   'title': 'In the Land of the Head Hunters'},
#  {'_id': ObjectId('61e618c4f599bd3513db469b'),
#   'languages': ['English'],
#   'title': 'Judith of Bethulia'},
#  {'_id': ObjectId('61e618c4f599bd3513db469c'),
#   'languages': ['English'],
#   'title': 'Laughing Gas'},
#  {'_id': ObjectId('61e618c4f599bd3513db469d'),
#   'languages': ['English'],
#   'title': 'The Knockout'},
#  {'_id': ObjectId('61e618c4f599bd3513db469e'),
#   'languages': ['English'],
#   'title': 'Mabel at the Wheel'},
#  {'_id': ObjectId('61e618c4f599bd3513db469f'),
#   'languages': ['English'],
#   'title': "Mabel's Married Life"},
#  {'_id': ObjectId('61e618c4f599bd3513db46a0'),
#   'languages': ['English'],
#   'title': 'Making a Living'},
#  {'_id': ObjectId('61e618c4f599bd3513db46a1'),
#   'languages': ['English'],
#   'title': 'The Ocean Waif'}]
